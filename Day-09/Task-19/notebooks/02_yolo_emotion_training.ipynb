# %%
# !unzip emotion-yolo.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: emotion_yolo/images/val/happy_PrivateTest_35915421.jpg
#  extracting: emotion_yolo/images/val/fear_PublicTest_4536412.jpg
#  extracting: emotion_yolo/images/val/happy_PublicTest_7797976.jpg
#  extracting: emotion_yolo/images/val/angry_PrivateTest_98403294.jpg
#  extracting: emotion_yolo/images/val/happy_PrivateTest_19304106.jpg
#  extracting: emotion_yolo/images/val/angry_PrivateTest_1809180.jpg
#  extracting: emotion_yolo/images/val/happy_PublicTest_81626629.jpg
#  extracting: emotion_yolo/images/val/fear_PublicTest_13590004.jpg
#  extracting: emotion_yolo/images/val/happy_PublicTest_64717014.jpg
#  extracting: emotion_yolo/images/val/surprise_PrivateTest_36889392.jpg
#  extracting: emotion_yolo/images/val/neutral_PrivateTest_39987047.jpg
#  extracting: emotion_yolo/images/val/happy_PublicTest_65949833.jpg
#  extracting: emotion_yolo/images/val/angry_PublicTest_65820617.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model.train(
    data="/content/emotion_yolo/data.yaml",
    epochs=20,
    imgsz=64,
    batch=64
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
