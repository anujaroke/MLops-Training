# %% [markdown]
# **Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import joblib

# %% [markdown]
# **Load Dataset**

# %%
df=pd.read_csv('/content/ai4i2020.csv')

# %% [markdown]
# **Input and Output**

# %%
X=df[[
    'Air temperature [K]',
    'Rotational speed [rpm]',
    'Torque [Nm]',
    'Tool wear [min]'
]]

y=df[['Process temperature [K]']]

# %% [markdown]
# **Model**

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# **Predictions**

# %%
predictions=model.predict(X)
predictions
# Out:
# array([[308.75873021],
#        [308.82999487],
#        [308.75276044],
#        ...,
#        [309.35153257],
#        [309.34711275],
#        [309.35288723]])

# %% [markdown]
# **MSE**

# %%
mse=mean_squared_error(y,predictions)
print(mse)
# Out:
# 0.5115862237963301

# %% [markdown]
# **Coef and Intercept**

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[ 6.49915258e-01 -8.20600778e-05 -1.58677594e-03  3.07535752e-05]]
# [115.2141811]

# %% [markdown]
# **Visualise Actual vs Predicted**

# %%
plt.scatter(y,predictions)
plt.xlabel("Actual Temperature")
plt.ylabel("Predicted Temperature")
plt.show()

# %% [markdown]
# **Save and Load the Model**

# %%
joblib.dump(model,'multivariable_model.pkl')
loaded=joblib.load('multivariable_model.pkl')
p=loaded.predict(X)
p
# Out:
# [[308.75873021]
#  [308.82999487]
#  [308.75276044]
#  ...
#  [309.35153257]
#  [309.34711275]
#  [309.35288723]]
